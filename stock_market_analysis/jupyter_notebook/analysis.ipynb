# %%
DIVIDEND_ANALYSIS_PATH = r"W:\Stock-market-analysis\stock_market_analysis\database\analysis\dividend_analysis.json"

# %%
import json
import pandas as pd

#from commun import utils, constants as k
from commun import utils, constants as k

json_data = utils.read_json_file(f"{DIVIDEND_ANALYSIS_PATH}")

df = pd.DataFrame(json_data)

df
# Out:
#                                      Entreprise Ticker    BPA ($)  \
# 0                                    Apple Inc.   AAPL   6.150000
# 1                                      BCE Inc.    BCE   3.140000
# 2                          Royal Bank of Canada     RY  11.088621
# 3                     The Toronto-Dominion Bank     TD   9.588491
# 4                              Bank of Montreal    BMO  20.917450
# 5   International Business Machines Corporation    IBM   6.410000
# 6                       The Bank of Nova Scotia    BNS   8.168040
# 7                     Realty Income Corporation      O   0.870000
# 8                            Target Corporation    TGT  14.230000
# 9                             Johnson & Johnson    JNJ   7.930000
# 10                                Enbridge Inc.    ENB   3.063861
# 11                        TC Energy Corporation    TRP   2.080000
#
#     Croiss. BPA (%)  Div Annuel ($)  Croiss. Div (%)  Prix action ($)  \
# ...
