# %%
DIVIDEND_ANALYSIS_PATH = r"W:\Stock-market-analysis\stock_market_analysis\database\analysis\dividend_analysis.json"

# %%
import json
import pandas as pd

#from commun import utils, constants as k
from commun import utils, constants as k

json_data = utils.read_json_file(f"{DIVIDEND_ANALYSIS_PATH}")

df = pd.DataFrame(json_data)

df
# Out:
#                                           Entreprise Ticker  BPA ($)  \
# 0         ProShares S&P 500 Dividend Aristocrats ETF   NOBL        0
# 1  ProShares S&P MidCap 400 Dividend Aristocrats ETF   REGL        0
# 2        ProShares Russell 2000 Dividend Growers ETF   SMDV        0
# 3          ProShares Russell US Dividend Growers ETF   TMDV        0
# 4  ProShares S&P Technology Dividend Aristocrats ETF    TDV        0
# 5           ProShares MSCI EAFE Dividend Growers ETF   EFAD        0
# 6         ProShares MSCI Europe Dividend Growers ETF   EUDV        0
# 7  ProShares MSCI Emerging Markets Dividend Growe...   EMDV        0
#
#    Croiss. BPA (%)  Div Annuel ($)  Croiss. Div (%)  Prix action ($)  \
# 0                0           1.743         9.038182          90.6000
# 1                0           1.662        19.521122          71.8200
# 2                0           1.539        15.303229          61.6935
# 3                0           1.155         6.394977          47.3300
# 4                0           0.923         8.799795          55.0900
# 5                0           0.623        -1.463699          35.2900
# 6                0           0.713        -0.119642          40.1216
# 7                0           1.662         5.259177          44.8524
#
#    Rendement (%)  Croiss. estimer (%)  Performance (%)  \
# 0       1.923841                    0                0
# 1       2.314119                    0                0
# 2       2.494590                    0                0
# 3       2.440313                    0                0
# 4       1.675440                    0                0
# 5       1.765373                    0                0
# 6       1.777098                    0                0
# 7       3.705487                    0                0
#
#    Distribution Profit (%)  Aristocrat dividend
# 0                        0                    3
# 1                        0                    1
# 2                        0                    2
# 3                        0                    1
# 4                        0                    4
# 5                        0                    3
# 6                        0                    2
# 7                        0                    2
