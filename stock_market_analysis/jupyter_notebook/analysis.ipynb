# %%
DIVIDEND_ANALYSIS_PATH = r"V:\Stock-market-analysis\stock_market_analysis\database\analysis\dividend_analysis.json"

# %%
import json
import pandas as pd

#from commun import utils, constants as k
from commun import utils, constants as k

json_data = utils.read_json_file(f"{DIVIDEND_ANALYSIS_PATH}")

df = pd.DataFrame(json_data)

df
# Out:
#                   Entreprise Ticker    BPA ($)  Croiss. BPA (%)  \
# 0       Royal Bank of Canada     RY  11.088621         5.736059
# 1           Bank of Montreal    BMO  20.917450        20.627123
# 2  The Toronto-Dominion Bank     TD   9.588491         9.756628
# 3    The Bank of Nova Scotia    BNS   8.168040         3.431720
#
#    Div Annuel ($)  Croiss. Div (%)  Prix action ($)  Rendement (%)  \
# 0        3.830822         6.811983            95.02       4.031596
# 1        5.584000         7.068177            91.16       6.125494
# 2        2.936000         9.311944            65.35       4.492731
# 3        4.130000         5.210540            49.07       8.416548
#
#    Croiss. estimer (%)  Performance (%)  Distribution Profit (%)  \
# 0             6.274021         9.767654                34.547326
# 1            10.000000        26.752617                26.695414
# 2             9.534286        14.249359                30.620042
# 3             4.321130        11.848268                50.562929
#
#    Aristocrat dividend (number reduce)
# 0                                    4
# 1                                    7
# 2                                    6
# 3                                   10
